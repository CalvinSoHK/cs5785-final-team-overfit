# %%
import import_ipynb
import Helper as lib
import operator
import numpy as np
# Out:
# importing Jupyter notebook from Helper.ipynb

# %%
# First get the description data
desc_data = lib.GetDescriptionData()

# %%
# Then collect tag data
tag_data = lib.GetTagData()

# %%
train_feature_data = lib.GetFeaturesFileData('data/features_train/features_resnet1000_train.csv')
test_feature_data = lib.GetFeaturesFileData('data/features_test/features_resnet1000_test.csv')

# %%
# Remove the extra image file name on the front
stripped_feature_data = []

for i in range(len(desc_data[0])):
    new_vector = train_feature_data[i][1:1001]
    new_vector = [float(i) for i in new_vector]
    stripped_feature_data.append(new_vector)
stripped_feature_data = np.array(stripped_feature_data)

# Do the same for test features
# First sort by the first index so its numbered in order
test_feature_data.sort(key=lambda x: x[0])
stripped_feature_test_data = []
for i in range(len(desc_data[1])):
    new_vector = test_feature_data[i][1:1001]
    new_vector = [float(i) for i in new_vector]
    stripped_feature_test_data.append(new_vector)
stripped_feature_test_data = np.array(stripped_feature_test_data)

# %%
# Create the bag of words representation of the whole data we want

# Get a combination of descriptions and tags from training set
COMBINED_TRAIN_DATA = lib.CombineDescAndTags(desc_data[0], tag_data[0])
COMBINED_TEST_DATA = lib.CombineDescAndTags(desc_data[1], tag_data[1])

# Sanity check
STANDARD_BAG_VECTOR = lib.GetBagOfWordsVector(desc_data[0])
print(len(STANDARD_BAG_VECTOR))

# First create a list of word called bag of words vector from training data
DESC_BAG_VECTOR = lib.GetBagOfWordsVector(COMBINED_TRAIN_DATA)
print(len(DESC_BAG_VECTOR))

# Second, convert our represnetation of the test_data with this vector
TAGS_AS_DESC = lib.ConvertTagToDescFormat(tag_data[1])
TRAIN_DESC_BAG_VECTORS = lib.ConvertDescToBagVector(COMBINED_TRAIN_DATA, DESC_BAG_VECTOR)
TEST_DESC_BAG_VECTORS = lib.ConvertDescToBagVector(COMBINED_TEST_DATA, DESC_BAG_VECTOR)
print('complete')

# OVER FITTING. Can't use description as a search...
# Out:
# 7660
# 7678
# complete

# %%
# reference: https://stackoverflow.com/questions/1401712/how-can-the-euclidean-distance-be-calculated-with-numpy
def get_euclidean_distance(a, b):
    a = np.array(a, dtype=float)
    b = np.array(b, dtype=float)
    return np.linalg.norm(a - b)

# %%
# Uses the already calculated bag of words representation of the data to guess which images are closest
def ScoreBag(feature_data = [], search_list =str, dictionary = [], training_image_data = [], training_feature_data = [], pools = int):

        # First preprocess our search into words that would compare to our bag of words vector
        search_string = ''
        for word in search_list:
            search_string += word + ' '
        search = lib.PreProcess(search_string)
        
        # Create a list of lists, where the first index is the image index, and the second list is a list of scores.
        # The indexes in the second list refer to which index word was searched to produce it from the search terms.
        score_list = []
        
        # Generate the unique words in our search list
        unique_words = []  
        for word in search:     
            if word in dictionary:
                unique_words.append(word)    
            # Removes duplicates
            unique_words = list(set(unique_words))
        
        # Change image data, and dictionary,  to list
        training_image_data = training_image_data.tolist()
        dictionary = dictionary.tolist()
        
        # For each search term, if it exists in the bag of words vector dictionary, 
        # score how related each image is to that word
        for i in range(len(training_image_data)):     
            # Sum up the count for all unique words
            count = 0
            for word in unique_words:
                if word in dictionary:
                    count += training_image_data[i][dictionary.index(word)]
            # Append new entry
            score_list.append([i, count])
        
        # After calculating the scores, pick the highest twenty and return them
        # First sort the whole list by the scores
        score_list.sort(key=lambda x: x[1])
        
        # Reverse the list
        score_list = list(reversed(score_list))
        
        # This index is the image we found to be the closest within training data
        image_indexes = score_list[:pools - 1]
        size = int(20/pools)
        
        # Now compare all test image features to this image
        chosen_index = []
        for image_index in image_indexes:
            train_feature = training_feature_data[image_index]
            differences = []
            for i in range(len(feature_data)):
                diff = get_euclidean_distance(train_feature, feature_data[i])
                differences.append([i, diff])        
            differences.sort(key = lambda x:x[1])
            for i in range(size):
                counter = i
                length = len(chosen_index)                
                # Only add that image if it isn't already in the list
                while(length == len(chosen_index)):
                    if differences[counter][0] not in chosen_index:
                        chosen_index.append(differences[counter][0])
                    else:
                        counter += 1
            # If this is the last one we are checking
            if image_indexes.index(image_index) == len(image_indexes):
                counter = i
                while(len(chosen_index) < 20):
                    chosen_index.append(differences[counter][0])
                    counter += 1
                    
        # Remove the scores and only keep the indexes
        print(chosen_index)
        return chosen_index

# %%
print(len(TEST_DESC_BAG_VECTORS))
# Out:
# 2000

# %%
search_index = 5
search = desc_data[1][search_index]
print(search)
print(TEST_DESC_BAG_VECTORS[search_index])
guesses = ScoreBag(stripped_feature_test_data, search, DESC_BAG_VECTOR, TRAIN_DESC_BAG_VECTORS, stripped_feature_data, 4)
print('Guessed image:')
lib.DisplayImages(guesses, 'test')
# Out:
# ['man' 'trick' 'skateboard' 'skateboarder' 'trick' 'air' 'wooden' 'ramp'
#  'blue' 'sky' 'cloud' 'background' 'person' 'perform' 'trick' 'skateboard'
#  'skateboarder' 'jump' 'ramp' 'man' 'jump' 'skateboard' 'park']
# [2 0 0 ... 0 0 0]
# [1468, 1957, 1152, 242, 1187, 737, 746, 1327, 360, 242, 514, 675, 737, 1565, 1932]
# Guessed image:
# Image 1468
# Image 1957
# Image 1152
# Image 242
# Image 1187
# Image 737
# Image 746
# Image 1327
# Image 360
# Image 242
# Image 514
# Image 675
# Image 737
# Image 1565
# Image 1932

# %%
# Try running ScoreBag and see accuracy with below
def RunScoreBag(test_desc = [], image_data = [], dictionary = []):
    score = 0
    batch = 0
    counter = 0
    guess_list = []
    for description in test_desc:
        guesses = ScoreBag(image_data, description, dictionary)
        guess_list.append(guesses)
        if counter in guesses:
            score += 1
            
        if counter > batch * 100:
            print('Progress:' + str(counter) + '/' + str(len(test_desc)))
            batch +=1
        
        counter += 1
    
    percentage = score / len(test_desc)
    print('Overall score was: ' + str(percentage))
    return guess_list

# %%
guess_submission = RunScoreBag(desc_data[1][:100], TEST_DESC_BAG_VECTORS, DESC_BAG_VECTOR)
# Out:
# ['front', 'woman', 'doorway', 'planters', 'cell', 'black', 'along', 'street', 'blue', 'side', 'watch', 'check', 'phone', 'entrance', 'talk', 'wear', 'past', 'build', 'sidewalk', 'walk']
# ['large', 'small', 'plate', 'cake', 'slice', 'quarter', 'food', 'piece', 'slab', 'flowery', 'angel', 'contain', 'top', 'sit', 'yellow', 'upon']
# Progress:1/100
# ['shin', 'sign', 'street', 'window', 'picture', 'overhead', 'light', 'intersection', 'fly', 'airplane', 'traffic', 'sun', 'group', 'stoplight', 'sit', 'several', 'surround']
# ['pair', 'middle', 'two', 'uniform', 'officer', 'people', 'side', 'ride', 'neon', 'police', 'horse', 'sandy', 'rid', 'beach', 'lot', 'vest', 'mean']
# ['booths', 'people', 'adults', 'couple', 'woman', 'use', 'telephone', 'machine', 'soda', 'phone', 'next', 'man', 'talk', 'public', 'outdoors', 'stand', 'pay', 'together', 'adjacent']
# ['park', 'blue', 'cloud', 'trick', 'ramp', 'perform', 'wooden', 'person', 'jump', 'air', 'sky', 'man', 'skateboard', 'background', 'skateboarder']
# ['pair', 'trick', 'slope', 'person', 'get', 'airborne', 'mid', 'slop', 'skier', 'jump', 'air', 'ski']
# ['gesture', 'toward', 'next', 'grass', 'lawn', 'build', 'show', 'stand', 'guy', 'young', 'pose', 'wildlife', 'exhibit', 'grassy', 'man', 'zebra']
# ['truck', 'orange', 'garage', 'inside', 'park', 'room', 'old', 'red', 'engine', 'build', 'work', 'model', 'station', 'display', 'antique', 'sit', 'alone', 'fire']
# ['ready', 'skateboarders', 'ramp', 'people', 'rest', 'stand', 'four', 'boys', 'guy', 'skate', 'group', 'top', 'board', 'skateboard']
# ['sign', 'hang', 'picture', 'light', 'leave', 'road', 'pole', 'vehicles', 'city', 'white', 'traffic', 'green', 'turn', 'park', 'street', 'right', 'side', 'near', 'lot', 'sit', 'busy', 'upside', 'many', 'build', 'wooden']
# ['ramp', 'light', 'night', 'air', 'pool', 'boy', 'bowl', 'person', 'board', 'skateboard', 'skateboarder', 'bright', 'park', 'flip', 'side', 'man', 'trick', 'showcasing', 'perform', 'dry', 'rid', 'skate']
# ['vehicle', 'get', 'two', 'road', 'compact', 'desert', 'things', 'drive', 'white', 'flat', 'board', 'surf', 'park', 'onto', 'sport', 'utility', 'sandy', 'open', 'man', 'dirt', 'car', 'back', 'roof', 'stand', 'door']
# ['hold', 'middle', 'skiers', 'next', 'wear', 'picture', 'people', 'snowstorm', 'side', 'stand', 'pose', 'ski', 'snow', 'two']
# ['others', 'people', 'pose', 'two', 'background', 'tree', 'skier', 'group', 'snow', 'snowy', 'along', 'towards', 'surface', 'three', 'ski', 'men', 'wear', 'slope', 'stand', 'rid', 'walk']
# ['load', 'sauce', 'vegetable', 'cut', 'melt', 'slice', 'toppings', 'bell', 'piece', 'cutter', 'pepper', 'board', 'green', 'vegetables', 'top', 'sit', 'pizza', 'wooden', 'cheese', 'meat']
# ['hold', 'field', 'male', 'close', 'smile', 'build', 'person', 'tan', 'read', 'frisbee', 'man', 'yellow', 'shirt']
# ['hold', 'road', 'two', 'jacket', 'street', 'side', 'streetlights', 'light', 'stand', 'tan', 'near', 'traffic', 'hand', 'couple', 'next', 'man', 'carry']
# ['elephant', 'back', 'people', 'shady', 'trail', 'couple', 'rid', 'top', 'group', 'canopy', 'forest']
# ['ocean', 'surfboard', 'attempt', 'stand', 'surfer', 'tiny', 'rid', 'come', 'man', 'wave', 'prepare', 'shore']
# ['unusual', 'plaque', 'different', 'two', 'show', 'front', 'write', 'small', 'green', 'various', 'museum', 'automobile', 'cars', 'shade', 'car', 'specialty', 'box', 'display', 'motorcycle']
# ['hold', 'nice', 'orange', 'ocean', 'blue', 'sky', 'freeze', 'water', 'view', 'frisbee', 'next', 'front', 'body', 'background', 'big']
# ['ripe', 'fruit', 'close', 'pile', 'neatly', 'stand', 'host', 'stack', 'top', 'oranges', 'lot', 'dozens', 'sit', 'bunch']
# ['toilet', 'bathroom', 'trash', 'sink', 'wooden', 'floor', 'seat', 'design', 'rather', 'older', 'ornately', 'open', 'photo', 'tile', 'dirty']
# ['hold', 'field', 'action', 'diamond', 'look', 'throw', 'pitcher', 'player', 'stadium', 'watch', 'baseball', 'stand', 'crowd', 'fly', 'game', 'players', 'bat']
# ['people', 'kid', 'stand', 'fly', 'child', 'beach', 'top', 'couple', 'kite', 'woman']
# ['single', 'place', 'platter', 'whole', 'plate', 'pizza', 'buffet', 'slice', 'piece', 'warm', 'table', 'serve', 'pan', 'display', 'next', 'sit', 'delicious']
# ['hold', 'play', 'leg', 'blue', 'player', 'racquet', 'racket', 'professional', 'stand', 'hand', 'court', 'one', 'man', 'tennis']
# ['cover', 'sauce', 'many', 'plate', 'pizzas', 'pizza', 'table', 'pie', 'flat', 'pan', 'utensils', 'top', 'toppings', 'two', 'sit', 'sliver', 'image', 'contain']
# ['hold', 'lie', 'around', 'bucket', 'picture', 'lean', 'pose', 'contain', 'photo', 'message', 'students', 'weather', 'write', 'group', 'black', 'teens', 'girls', 'park', 'red', 'three', 'near', 'plastic', 'one', 'chalk', 'wood', 'kid', 'sidewalk', 'gray', 'bench']
# ['hold', 'suit', 'people', 'town', 'golden', 'horseback', 'surround', 'ceremonial', 'deck', 'person', 'asian', 'white', 'horse', 'go', 'local', 'foot', 'head', 'parade', 'cover', 'street', 'guy', 'man', 'rider', 'march', 'procession', 'rid', 'umbrella']
# ['hold', 'different', 'cabinet', 'dish', 'pot', 'curio', 'assortment', 'case', 'multiple', 'fill', 'glass', 'next', 'sit', 'several', 'size', 'ceramic', 'vases', 'shelf', 'display']
# ['end', 'morning', 'front', 'road', 'big', 'tree', 'drive', 'white', 'head', 'park', 'bus', 'mass', 'blue', 'round', 'closeup', 'next', 'number', 'transit', 'make', 'cloudy', 'route', 'airy']
# ['fruit', 'pile', 'fill', 'bag', 'sit', 'grocery', 'white', 'grapes', 'store', 'display', 'next', 'apples', 'bunch', 'nut', 'shelf']
# ['around', 'turn', 'ocean', 'pass', 'hill', 'long', 'track', 'outside', 'water', 'rid', 'near', 'come', 'grassy', 'show', 'corner', 'train', 'beside']
# ['bed', 'couple', 'two', 'road', 'front', 'truck', 'flatbed', 'drive', 'intersection', 'behind', 'come', 'attach', 'park', 'street', 'outside', 'one', 'sit', 'large', 'build']
# ['hold', 'cellphone', 'pull', 'hair', 'hunch', 'back', 'clutch', 'lean', 'phone', 'ear', 'bend', 'cell', 'talk', 'girl', 'woman']
# ['hold', 'field', 'blue', 'smile', 'professional', 'sidewalk', 'stand', 'young', 'umbrella', 'next', 'rain', 'girl', 'woman']
# ['cover', 'counter', 'around', 'foil', 'dish', 'wrap', 'tray', 'aluminum', 'tin', 'item', 'bake', 'top', 'pan', 'something', 'kitchen']
# ['cream', 'color', 'orange', 'lay', 'white', 'pumpkin', 'display', 'look', 'vegetables', 'next', 'sit', 'large', 'toward', 'back', 'cat', 'wooden', 'camera', 'walk', 'bench']
# ['hold', 'show', 'two', 'front', 'prepare', 'video', 'another', 'work', 'computer', 'flat', 'wii', 'play', 'guy', 'game', 'one', 'men', 'tv', 'controllers', 'stand', 'screen']
# ['style', 'gold', 'face', 'crown', 'clock', 'metal', 'old', 'red', 'photograph', 'gas', 'fancy', 'store', 'top', 'ornate', 'pump']
# ['hold', 'kneel', 'ball', 'wear', 'player', 'picture', 'baseball', 'pose', 'uniform', 'outfit', 'man', 'bat']
# ['little', 'two', 'front', 'background', 'big', 'follow', 'distance', 'person', 'hill', 'horse', 'behind', 'grassy', 'sheep', 'green', 'animals', 'grass', 'blue', 'sky', 'next', 'man', 'castle', 'far', 'build', 'cloudy', 'stand', 'walk']
# ['counter', 'scissor', 'cook', 'leave', 'knife', 'utensils', 'bar', 'assortment', 'amongst', 'various', 'cover', 'set', 'top', 'several', 'cup', 'items', 'desk', 'bottle', 'measure', 'make', 'include', 'kitchen', 'paraphernalia']
# ['miniature', 'flashlight', 'banana', 'stereo', 'little', 'radio', 'box', 'include', 'chair', 'white', 'tiny', 'assortment', 'behind', 'top', 'rotten', 'small', 'background', 'items']
# ['cement', 'desert', 'person', 'blurry', 'skateboard', 'skateboarder', 'single', 'travel', 'along', 'blue', 'near', 'pant', 'skater', 'shirt', 'boarder', 'planter', 'photograph', 'walkway', 'sidewalk', 'pave', 'rid', 'skate', 'glide', 'someone']
# ['body', 'ocean', 'lighthouse', 'wooden', 'lake', 'side', 'line', 'row', 'overlook', 'water', 'near', 'next', 'sit', 'bench', 'several']
# ['rope', 'string', 'hang', 'street', 'fill', 'stop', 'people', 'city', 'cars', 'line', 'light', 'town', 'traffic', 'dark', 'road', 'bunch', 'image']
# ['hold', 'different', 'bunch', 'pair', 'clock', 'person', 'sand', 'small', 'vary', 'style', 'close', 'watch', 'variety', 'human', 'pocket', 'someones', 'many', 'hand', 'type', 'someone']
# ['wild', 'field', 'giraffe', 'somewhat', 'edge', 'wooded', 'distant', 'area', 'tree', 'giraffes', 'plain', 'stand', 'four', 'eat', 'grassy', 'front', 'background', 'several']
# ['hold', 'decorations', 'smile', 'beach', 'group', 'small', 'banner', 'look', 'colorful', 'long', 'near', 'outside', 'man', 'kite', 'large', 'men', 'stretch', 'build', 'stand']
# ['catch', 'play', 'leg', 'field', 'leap', 'gentleman', 'front', 'dog', 'another', 'get', 'jump', 'bend', 'frisbee', 'man', 'background']
# ['tobacco', 'sign', 'people', 'front', 'propeller', 'war', 'area', 'runway', 'world', 'amongst', 'warn', 'plan', 'museum', 'smoke', 'airplane', 'outdoor', 'sit', 'allow', 'walk', 'yellow', 'airport']
# ['toilet', 'home', 'rack', 'slide', 'divider', 'bathtub', 'glass', 'interior', 'white', 'dark', 'bathroom', 'tub', 'towel', 'tile', 'black']
# ['hold', 'leg', 'lie', 'handle', 'stomach', 'fully', 'lay', 'bed', 'clothe', 'half', 'top', 'purse', 'one', 'beautiful', 'girl', 'woman', 'handbag']
# ['hold', 'large', 'fork', 'assort', 'look', 'wear', 'pizza', 'smile', 'slice', 'glass', 'lady', 'toppings', 'delicious', 'woman']
# ['brown', 'large', 'park', 'ship', 'background', 'blue', 'walkway', 'boat', 'model', 'foreground', 'float', 'cruise', 'white', 'face', 'next', 'bench', 'black', 'river']
# ['grind', 'hide', 'picture', 'woman', 'skiis', 'backyard', 'person', 'cold', 'face', 'snow', 'snowy', 'cover', 'bundle', 'set', 'outside', 'ski', 'sky', 'wear', 'day', 'house', 'stand', 'young', 'paraphernalia']
# ['hold', 'athletes', 'plate', 'teammates', 'players', 'home', 'place', 'take', 'look', 'watch', 'baseball', 'game', 'swing', 'next', 'several', 'batter', 'player', 'base', 'bat']
# ['around', 'see', 'home', 'chrome', 'wire', 'room', 'electronic', 'computer', 'devise', 'glass', 'equipment', 'top', 'sit', 'desk', 'many', 'office', 'desktop', 'table', 'tangle']
# ['inside', 'picture', 'trim', 'microwave', 'room', 'area', 'wall', 'white', 'hallway', 'bright', 'refrigerator', 'red', 'paint', 'colorful', 'oven', 'accent', 'sit', 'door', 'kitchen']
# ['people', 'military', 'event', 'two', 'show', 'war', 'world', 'group', 'green', 'park', 'grass', 'look', 'lawn', 'near', 'top', 'vintage', 'army', 'stand', 'dark', 'display', 'motorcycle']
# ['front', 'home', 'deck', 'area', 'slide', 'overlook', 'collar', 'look', 'pink', 'onto', 'dog', 'glass', 'outside', 'sit', 'large', 'porch', 'stand', 'door', 'star']
# ['grassy', 'field', 'giraffe', 'wooded', 'shoulder', 'close', 'lush', 'area', 'picture', 'zoo', 'stand', 'top', 'head', 'green', 'zebra']
# ['seafood', 'bowl', 'plate', 'dish', 'carrots', 'rice', 'vegetables', 'broccoli', 'food', 'include', 'white', 'serve', 'meat', 'prepare']
# ['desk', 'space', 'look', 'man', 'smile', 'work', 'sit', 'computer', 'table', 'phone', 'use', 'star', 'monitor', 'screen']
# ['entertainment', 'middle', 'furniture', 'room', 'basic', 'look', 'area', 'unit', 'coffee', 'wooden', 'piece', 'sofa', 'table', 'live', 'stand', 'formal', 'empty', 'sit']
# ['plant', 'different', 'couple', 'bunch', 'remote', 'wall', 'computer', 'cell', 'electronics', 'monitor', 'green', 'cover', 'keyboards', 'three', 'set', 'phone', 'top', 'next', 'sit', 'television', 'desk', 'desktop', 'table', 'computers']
# ['plant', 'haul', 'wooded', 'pull', 'area', 'piece', 'drive', 'go', 'along', 'away', 'long', 'power', 'lot', 'one', 'next', 'several', 'track', 'four', 'multicolored', 'empty', 'train']
# ['large', 'rail', 'inside', 'passenger', 'sleek', 'platform', 'stop', 'red', 'people', 'silver', 'track', 'modern', 'station', 'way', 'metro', 'sit', 'train']
# ['low', 'commercial', 'bridge', 'fly', 'white', 'dock', 'take', 'jet', 'passenger', 'long', 'loom', 'airplane', 'top', 'sky', 'large', 'cloudy', 'water', 'aircraft', 'body', 'airport']
# ['hold', 'picture', 'mobile', 'coat', 'photo', 'woman', 'capture', 'person', 'use', 'cell', 'take', 'jacket', 'look', 'flip', 'phone', 'parka', 'hood', 'heavy', 'wear', 'camera']
# ['travel', 'field', 'passenger', 'high', 'speed', 'commuter', 'rural', 'area', 'day', 'long', 'track', 'move', 'countryside', 'go', 'open', 'train', 'clear']
# ['ripe', 'brown', 'fruit', 'bowl', 'fill', 'pears', 'include', 'table', 'basket', 'bananas', 'top', 'image', 'next', 'sit', 'black']
# ['couch', 'light', 'modern', 'two', 'room', 'wall', 'black', 'stream', 'windows', 'blue', 'fill', 'red', 'paint', 'view', 'unique', 'furniture', 'coffee', 'live', 'table', 'dark']
# ['mountains', 'cap', 'still', 'front', 'reflections', 'lake', 'boat', 'sit', 'adorn', 'water', 'white', 'lone', 'calm', 'snow', 'small', 'mountainous', 'mountain']
# ['along', 'field', 'herd', 'wild', 'shrubs', 'walk', 'grass', 'look', 'zebras', 'distance', 'plain', 'stand', 'pack', 'grassy', 'bunch', 'several', 'zebra']
# ['tangerines', 'fruit', 'bowl', 'cut', 'fill', 'glass', 'strawberries', 'sit', 'table', 'peel', 'contain', 'oranges', 'lot', 'small', 'chop']
# ['field', 'park', 'shape', 'hill', 'fly', 'airplane', 'air', 'man', 'kite', 'plan']
# ['lush', 'elephant', 'lean', 'elephants', 'nuzzle', 'two', 'mother', 'baby', 'small', 'cuddle', 'green', 'field', 'towards', 'grass', 'mom', 'pasture', 'hillside', 'larger', 'young', 'stand']
# ['desk', 'corner', 'laptop', 'wooden', 'computer', 'plain', 'chair', 'desktop', 'top', 'monitor', 'sit', 'black', 'computers']
# ['tractor', 'boat', 'bed', 'trailer', 'road', 'carry', 'truck', 'pull', 'flat', 'construction', 'site', 'semi', 'park', 'blue', 'transport', 'tow', 'sit', 'large', 'image']
# ['bakery', 'line', 'different', 'front', 'arrange', 'cabinet', 'flavor', 'assortment', 'case', 'donut', 'fill', 'glass', 'fruit', 'doughnuts', 'display', 'shop', 'rack', 'full', 'donuts']
# ['hold', 'fist', 'face', 'funny', 'make', 'package', 'guy', 'toothbrush', 'young', 'brand', 'brush', 'new', 'man', 'yell', 'tooth']
# ['refrigerator', 'look', 'photo', 'old', 'front', 'stand', 'kitchen', 'drink', 'eat', 'fridge', 'open', 'something', 'man']
# ['narrow', 'try', 'front', 'overtake', 'big', 'truck', 'nice', 'city', 'white', 'park', 'street', 'side', 'tall', 'huge', 'build', 'day', 'box', 'word', 'train']
# ['children', 'field', 'juvenile', 'play', 'around', 'ball', 'people', 'three', 'kid', 'young', 'kick', 'game', 'group', 'players', 'soccer']
# ['counter', 'different', 'bunch', 'tray', 'package', 'assortment', 'group', 'small', 'green', 'assort', 'fill', 'red', 'pile', 'onto', 'vegetables', 'top', 'sit', 'fresh', 'mix', 'table', 'meat', 'full']
# ['hold', 'pair', 'scissor', 'cut', 'paper', 'carefully', 'piece', 'glass', 'plastic', 'something', 'man', 'kind']
# ['along', 'lamp', 'chain', 'bicycle', 'blue', 'old', 'red', 'build', 'bike', 'sidewalk', 'light', 'lock', 'tie', 'near', 'post', 'front', 'pole']
# ['picture', 'room', 'area', 'wall', 'tree', 'sofa', 'decorate', 'fill', 'paint', 'nicely', 'bare', 'furniture', 'wood', 'decals', 'coffee', 'apartment', 'chair', 'live', 'match', 'table', 'floor', 'odd', 'leather']
# ['hold', 'suitcase', 'walk', 'pull', 'luggage', 'area', 'past', 'baggage', 'person', 'stand', 'traveler', 'behind', 'wheel', 'carousel', 'empty', 'man', 'busy', 'airport']
# ['feeder', 'bird', 'eat', 'white', 'outside', 'sit', 'yellow', 'black', 'perch']
# ['shape', 'plate', 'sandwich', 'bun', 'slice', 'fry', 'pull', 'meat', 'meal', 'white', 'fill', 'bread', 'potatoes', 'uniquely', 'sit', 'next', 'pork', 'beef', 'image']
# ['park', 'man', 'ramp', 'perform', 'person', 'young', 'jump', 'rid', 'skate', 'top', 'go', 'air', 'small', 'board', 'skateboard', 'skateboarder']
# ['mountains', 'horizon', 'sign', 'warn', 'car', 'street', 'green', 'cars', 'city', 'light', 'long', 'traffic', 'move', 'stoplight', 'show', 'road', 'call', 'take']
# ['light', 'night', 'background', 'clock', 'vehicles', 'brightly', 'city', 'drive', 'traffic', 'zoom', 'street', 'cars', 'tower', 'near', 'move', 'lot', 'busy', 'large', 'build', 'fast', 'image']
# ['picture', 'people', 'slope', 'side', 'snowboarders', 'gourd', 'snowboard', 'stand', 'four', 'pose', 'group', 'snow', 'next', 'board', 'surf']
# ['type', 'like', 'bear', 'jar', 'front', 'bunch', 'brown', 'honey', 'small', 'display', 'various', 'look', 'cute', 'next', 'sit', 'several', 'bottle', 'stand', 'teddy', 'stuff', 'containers']
# Overall score was: 1.0

# %%
print(guess_submission)
# Out:
# [[0, 1694, 844, 1808, 971, 798, 586, 1101, 996, 1963, 1467, 1458, 1142, 1138, 751, 173, 90, 1438, 259, 36, 1925], [1, 1071, 616, 601, 1939, 1824, 1959, 1835, 1790, 1456, 1121, 916, 833, 524, 504, 487, 293, 233, 177, 1932, 1758], [2, 216, 1830, 1664, 1050, 1026, 1844, 1606, 294, 1945, 1793, 1524, 1391, 1207, 1085, 1084, 762, 302, 263, 1668, 1303], [3, 434, 1383, 1070, 1918, 1244, 1191, 399, 374, 159, 13, 1834, 1708, 1619, 1239, 972, 938, 886, 753, 1845, 1578], [4, 1808, 1694, 1690, 1101, 1256, 972, 844, 497, 1432, 1421, 248, 1915, 1843, 1651, 1407, 1290, 870, 7, 1985, 1505], [5, 1162, 599, 552, 1802, 1087, 905, 754, 597, 95, 1744, 1099, 1034, 630, 456, 1662, 1382, 969, 860, 452, 227], [1312, 6, 674, 673, 725, 452, 696, 1731, 1637, 1581, 126, 1992, 1219, 978, 738, 416, 258, 1822, 1419, 1061, 1048], [7, 484, 1938, 1407, 840, 1915, 902, 43, 1978, 1891, 1860, 1690, 1645, 1131, 1078, 214, 104, 1928, 1689, 1022, 984], [8, 788, 1366, 1058, 730, 281, 257, 1484, 1003, 583, 86, 1240, 1226, 1217, 960, 923, 588, 146, 1906, 1727, 1640], [9, 98, 1212, 1891, 1571, 1498, 1113, 705, 478, 120, 1550, 1544, 969, 666, 472, 1974, 1495, 1336, 1262, 1103, 1078], [10, 216, 1844, 1801, 1830, 925, 751, 331, 1664, 586, 569, 263, 1391, 48, 1945, 1668, 1606, 1532, 1050, 624, 522], [11, 599, 1495, 1891, 1099, 969, 705, 95, 1358, 630, 1744, 1662, 905, 5, 1802, 1262, 1162, 880, 793, 754, 597], [12, 724, 1891, 1676, 1560, 1287, 898, 1492, 1270, 1249, 972, 363, 1614, 1052, 952, 138, 114, 1570, 1383, 1381, 507], [13, 1186, 1924, 1825, 669, 98, 14, 1450, 1416, 488, 1723, 1497, 1461, 766, 732, 1263, 922, 913, 559, 426, 1976], [14, 669, 1924, 171, 98, 1637, 1186, 1148, 1825, 1461, 766, 1304, 732, 696, 13, 1731, 1497, 922, 913, 214, 1992], [15, 1463, 320, 1044, 342, 1302, 1288, 462, 1359, 627, 271, 26, 1974, 1835, 1210, 1202, 1010, 1783, 1531, 1224, 948], [16, 197, 1043, 372, 1897, 141, 823, 786, 619, 353, 1886, 1702, 1446, 1223, 1127, 1025, 250, 138, 102, 52, 1915], [17, 972, 294, 1830, 1078, 1043, 1915, 1606, 1263, 1050, 1022, 216, 141, 1844, 1801, 1643, 1450, 851, 559, 108, 1690], [18, 1719, 1191, 1173, 826, 742, 478, 120, 1980, 1815, 1737, 1637, 1544, 1543, 1448, 1148, 1120, 886, 824, 472, 434], [19, 1729, 1636, 274, 1782, 1265, 1201, 946, 1895, 1673, 337, 1761, 1590, 1443, 735, 1798, 1710, 1337, 1279, 1081, 742], [20, 1874, 1079, 1069, 62, 956, 358, 1634, 455, 105, 1330, 1242, 923, 393, 255, 1985, 1898, 1845, 1833, 1739, 1676], [21, 1354, 1170, 823, 786, 1470, 1865, 997, 995, 197, 141, 37, 16, 1702, 1197, 1043, 892, 882, 52, 1929, 1860], [22, 1045, 1189, 1144, 373, 9, 1546, 1485, 1427, 1110, 162, 142, 1888, 1651, 1561, 1249, 1219, 1157, 853, 837, 553], [23, 1685, 850, 1972, 1914, 1457, 273, 238, 201, 841, 603, 254, 117, 1714, 1216, 1064, 1805, 1666, 1386, 930, 518], [24, 327, 42, 1748, 1674, 1318, 910, 1493, 1275, 1063, 614, 529, 1842, 1780, 1631, 634, 564, 218, 59, 1677, 1541], [25, 399, 1375, 848, 1597, 413, 1572, 835, 671, 472, 344, 282, 1709, 1608, 876, 1971, 1918, 1910, 1689, 1501, 1070], [26, 293, 948, 626, 768, 1302, 1044, 765, 703, 471, 1783, 1568, 797, 627, 342, 185, 151, 1939, 1932, 1699, 1455], [27, 1717, 764, 1060, 1693, 215, 647, 509, 1688, 1476, 1374, 1282, 940, 237, 1951, 1558, 1328, 1083, 468, 209, 1901], [28, 1553, 393, 293, 26, 1783, 948, 768, 626, 1302, 1044, 765, 1035, 767, 721, 703, 432, 320, 151, 1699, 1531], [29, 1177, 1142, 981, 131, 1344, 1274, 1030, 1029, 922, 773, 679, 612, 571, 448, 436, 1829, 1788, 1641, 1601, 1409], [30, 1351, 1043, 159, 1746, 1479, 1002, 760, 753, 311, 1908, 1619, 1191, 911, 650, 580, 434, 374, 361, 1907, 1562], [31, 234, 100, 1894, 83, 1651, 1220, 1854, 1787, 1601, 283, 161, 1940, 1762, 1445, 1069, 1043, 892, 857, 828, 329], [32, 1817, 1654, 1412, 1227, 475, 816, 1509, 1342, 1287, 1199, 960, 129, 1942, 1792, 1791, 1508, 1381, 391, 272, 1340], [33, 1163, 1894, 1189, 1871, 1651, 695, 1887, 1777, 1110, 975, 890, 284, 147, 31, 1686, 1427, 1235, 828, 668, 534], [34, 686, 1949, 135, 1706, 1652, 638, 1310, 950, 734, 672, ...

# %%
for word in lib.ConvertDescToBagVector(lib.ConvertTagToDescFormat(tag_data[1]), DESC_BAG_VECTOR):
